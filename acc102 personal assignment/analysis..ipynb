# %%
"""
ANALYSIS - AAPL Stock Analysis Tool (ACC102 Track 4)

This project performs a complete quantitative stock analysis using data from the WRDS CRSP database,
including data extraction, cleaning, calculation, and visualization.

1. Data Source
The analysis uses three key tables from CRSP:
- dsf: daily stock data (price, return, volume, shares outstanding)
- stocknames: to convert ticker (AAPL) into unique PERMNO for accurate query
- dsi: market index return for performance comparison

2. Data Processing
Raw data is cleaned and processed using pandas:
- Convert date to datetime format
- Remove missing or invalid values
- Calculate adjusted price to eliminate split/dividend effects
- Compute market capitalization and cumulative return
- Standardize all numerical fields for reliable analysis

3. Analysis & Visualization
The tool provides four structured analysis modules:
- Overview: key metrics and data preview
- Price & Return: trend analysis of adjusted price and cumulative return
- Volume & Distribution: trading activity and return distribution
- Market Comparison: individual stock performance vs. market benchmark

4. Key Findings
AAPL shows a strong long-term upward trend with stable positive cumulative returns.
Return volatility is reasonable, and trading volume remains consistent.
The stock generally performs in line with or better than the overall market.

5. Tool Value
This dashboard allows users to complete professional stock analysis without coding,
automating data retrieval, calculation, charting, and interpretation.
"""
